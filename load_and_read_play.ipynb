# %%
import json
from crpapi import CRP

# %%
def create_crp_object(json_file='open_secrets_config.json',json_key='open_secrets_info'):
    with open(json_file) as f:
        data = json.load(f)
    
    user_values = data[json_key]
    crp = CRP(user_values['api_key'])
    return crp

# %%
crp = create_crp_object()

# %%
# get all basic state legislator information
states = [ \
    'AL','AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA','HI','ID','IL',\
          'IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT',\
          'NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI',\
          'SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']

legislators = []
for state in states:
    legislators.append(crp.candidates.get(state))

# %%
import pandas as pd

# %%
df_legislators = pd.DataFrame(columns = legislators[0][0]['@attributes'].keys())

# %%
# add basic legislator data into dataframe
for state in legislators:
    for candidate in state:
        if type(candidate)==dict:
            df_legislators = df_legislators.append(candidate['@attributes'],ignore_index=True)

# %%
df_legislators.cid[0]
# Out:
# 'N00035380'

# %%
# get memPFDprofiles for each legislator in df_legislators
mem_pfd_profiles = []
for cid in df_legislators.cid:
    try:
        mem_pfd_profiles.append(crp.candidates.pfd(cid))
    except:
        print('error with legislator id {}'.format(cid))
# Out:
# error with legislator id N00035187
# error with legislator id N00009918

# %%
df_legislators.head(1)
# Out:
#          cid      firstlast lastname party office gender first_elected  \
# 0  N00035380  Bradley Byrne    BYRNE     R   AL01      M          2013
#
#   exit_code             comments         phone  ...                  website  \
# 0        20  Lost Senate primary  202-225-4931  ...  https://byrne.house.gov
#
#                                     webform                   congress_office  \
# 0  https://byrne.house.gov/contact/email-me  119 Cannon House Office Building
#
#   bioguide_id votesmart_id  feccandid twitter_id youtube_url facebook_id  \
# 0     B001289        27584  H4AL01123   RepByrne                RepByrne
#
#     birthdate
# 0  1955-02-16
#
# [1 rows x 21 columns]

# %%
# get candContrib for each legislator in df_legislators
import re

cand_contrib = []
sen_years = ['2012', '2014', '2016', '2018', '2020']
rep_years = ['2018', '2020']
last_cid = None
last_year = None
for ix,cid in enumerate(df_legislators.cid):
    is_senate = re.search("S[12]", df_legislators.iloc[ix]['office'])
    if is_senate:
        years = sen_years
    else:
        years = rep_years
        
    for year in years:
        try:
            cand_contrib.append(crp.candidates.contrib(cid,cycle=year))
        except:
            print('error with legislator id {}, year {}'.format(cid,year))
            
        last_year = year
    
    last_cid = cid
# Out:
# error with legislator id N00035380, year 2020
# error with legislator id N00024817, year 2012
# error with legislator id N00024817, year 2014
# error with legislator id N00024817, year 2016
# error with legislator id N00035774, year 2012
# error with legislator id N00044298, year 2018
# error with legislator id N00036915, year 2012
# error with legislator id N00036915, year 2014
# error with legislator id N00030829, year 2020
# error with legislator id N00028133, year 2018
# error with legislator id N00028133, year 2020
# error with legislator id N00040876, year 2018
# error with legislator id N00040876, year 2020
# error with legislator id N00027510, year 2018
# error with legislator id N00027510, year 2020
# error with legislator id N00030608, year 2012
# error with legislator id N00030608, year 2014
# error with legislator id N00030608, year 2016
# error with legislator id N00030608, year 2018
# error with legislator id N00030608, year 2020
# error with legislator id N00030780, year 2012
# error with legislator id N00030780, year 2014
# error with legislator id N00030780, year 2016
# error with legislator id N00030780, year 2018
# error with legislator id N00030780, year 2020
# error with legislator id N00000575, year 2018
# error with legislator id N00000575, year 2020
# error with legislator id N00024842, year 2018
# error with legislator id N00024842, year 2020
# error with legislator id N00000615, year 2018
# error with legislator id N00000615, year 2020
# error with legislator id N00029070, year 2018
# error with legislator id N00029070, year 2020
# error with legislator id N00043421, year 2018
# error with legislator id N00043421, year 2020
# error with legislator id N00027566, year 2012
# error with legislator id N00027566, year 2014
# error with legislator id N00027566, year 2016
# error with legislator id N00027566, year 2018
# error with legislator id N00027566, year 2020
# error with legislator id N00031685, year 2012
# error with legislator id N00031685, year 2014
# error with legislator id N00031685, year 2016
# error with legislator id N00031685, year 2018
# error with legislator id N00031685, year 2020
# error with legislator id N00038414, year 2018
# error with legislator id N00038414, year 2020
# error with legislator id N00012508, year 2012
# error with legislator id N00012508, year 2014
# error with legislator id N00012508, year 2016
# error with legislator id N00012508, year 2018
# error with legislator id N00012508, year 2020
# error with legislator id N00031820, year 2012
# error with legislator id N00031820, year 2014
# error with legislator id N00031820, year 2016
# error with legislator id N00031820, year 2018
# error with legislator id N00031820, year 2020
# error with legislator id N00039503, year 2018
# error with legislator id N00039503, year 2020
# error with legislator id N00037442, year 2018
# error with legislator id N00037442, year 2020
# error with legislator id N00033220, year 2018
# error with legislator id N00033220, year 2020
# error with legislator id N00039777, year 2018
# error with legislator id N00039777, year 2020
# error with legislator id N00030642, year 2018
# error with legislator id N00030642, year 2020
# error with legislator id N00042403, year 2018
# error with legislator id N00042403, year 2020
# error with legislator id N00040133, year 2018
# error with legislator id N00040133, year 2020
# error with legislator id N00029662, year 2018
# error with legislator id N00029662, year 2020
# error with legislator id N00037422, year 2018
# error with legislator id N00037422, year 2020
# error with legislator id N00033449, year 2018
# error with legislator id N00033449, year 2020
# error with legislator id N00026335, year 2018
# error with legislator id N00026335, year 2020
# error with legislator id N00027462, year 2018
# error with legislator id N00027462, year 2020
# error with legislator id N00002942, year 2018
# error with legislator id N00002942, year 2020
# error with legislator id N00027514, year 2018
# error with legislator id N00027514, year 2020
# error with legislator id N00043319, year 2018
# error with legislator id N00043319, year 2020
# error with legislator id N00027626, year 2018
# error with legislator id N00027626, year 2020
# error with legislator id N00042808, year 2018
# error with legislator id N00042808, year 2020
# error with legislator id N00037269, year 2018
# error with legislator id N00037269, year 2020
# error with legislator id N00040007, year 2018
# error with legislator id N00040007, year 2020
# error with legislator id N00002884, year 2018
# error with legislator id N00002884, year 2020
# error with legislator id N00002893, year 2018
# error with legislator id N00002893, year 2020
# error with legislator id N00031317, year 2018
# error with legislator id N00031317, year 2020
# error with legislator id N00026106, year 2018
# error with legislator id N00026106, year 2020
# error with legislator id N00030650, year 2018
# error with legislator id N00030650, year 2020
# error with legislator id N00025337, year 2018
# error with legislator id N00025337, year 2020
# error with legislator id N00041561, year 2018
# error with legislator id N00041561, year 2020
# error with legislator id N00042811, year 2018
# error with legislator id N00042811, year 2020
# error with legislator id N00043290, year 2012
# error with legislator id N00043290, year 2014
# error with legislator id N00043290, year 2016
# error with legislator id N00043290, year 2018
# error with legislator id N00043290, year 2020
# error with legislator id N00030612, year 2012
# error with legislator id N00030612, year 2014
# error with legislator id N00030612, year 2016
# error with legislator id N00030612, year 2018
# error with legislator id N00030612, year 2020
# error with legislator id N00035346, year 2018
# error with legislator id N00035346, year 2020
# error with legislator id N00002674, year 2018
# error with legislator id N00002674, year 2020
# error with legislator id N00039090, year 2018
# error with legislator id N00039090, year 2020
# error with legislator id N00027848, year 2018
# error with legislator id N00027848, year 2020
# error with legislator id N00002577, year 2018
# error with legislator id N00002577, year 2020
# error with legislator id N00042813, year 2018
# error with legislator id N00042813, year 2020
# error with legislator id N00032416, year 2018
# error with legislator id N00032416, year 2020
# error with legislator id N00032457, year 2018
# error with legislator id N00032457, year 2020
# error with legislator id N00033518, year 2018
# error with legislator id N00033518, year 2020
# error with legislator id N00032243, year 2018
# error with legislator id N00032243, year 2020
# error with legislator id N00035347, year 2018
# error with legislator id N00035347, year 2020
# error with legislator id N00033720, year 2018
# error with legislator id N00033720, year 2020
# error with legislator id N00024871, year 2018
# error with legislator id N00024871, year 2020
# error with legislator id N00030788, year 2018
# error with legislator id N00030788, year 2020
# error with legislator id N00035516, year 2012
# error with legislator id N00035516, year 2014
# error with legislator id N00035516, year 2016
# error with legislator id N00035516, year 2018
# error with legislator id N00035516, year 2020
# error with legislator id N00002593, year 2012
# error with legislator id N00002593, year 2014
# error with legislator id N00002593, year 2016
# error with legislator id N00002593, year 2018
# error with legislator id N00002593, year 2020
# error with legislator id N00046125, year 2012
# error with legislator id N00046125, year 2014
# error with legislator id N00046125, year 2016
# error with legislator id N00046125, year 2018
# error with legislator id N00046125, year 2020
# error with legislator id N00025882, year 2018
# error with legislator id N00025882, year 2020
# error with legislator id N00033281, year 2018
# error with legislator id N00033281, year 2020
# error with legislator id N00028138, year 2012
# error with legislator id N00028138, year 2014
# error with legislator id N00028138, year 2016
# error with legislator id N00028138, year 2018
# error with legislator id N00028138, year 2020
# error with legislator id N00028139, year 2012
# error with legislator id N00028139, year 2014
# error with legislator id N00028139, year 2016
# error with legislator id N00028139, year 2018
# error with legislator id N00028139, year 2020
# error with legislator id N00041335, year 2018
# error with legislator id N00041335, year 2020
# error with legislator id N00006263, year 2018
# error with legislator id N00006263, year 2020
# error with legislator id N00029441, year 2012
# error with legislator id N00029441, year 2014
# error with legislator id N00029441, year 2016
# error with legislator id N00029441, year 2018
# error with legislator id N00029441, year 2020
# error with legislator id N00006267, year 2012
# error with legislator id N00006267, year 2014
# error with legislator id N00006267, year 2016
# error with legislator id N00006267, year 2018
# error with legislator id N00006267, year 2020
# error with legislator id N00004887, year 2018
# error with legislator id N00004887, year 2020
# error with legislator id N00035215, year 2018
# error with legislator id N00035215, year 2020
# error with legislator id N00027239, year 2018
# error with legislator id N00027239, year 2020
# error with legislator id N00042114, year 2018
# error with legislator id N00042114, year 2020
# error with legislator id N00030581, year 2018
# error with legislator id N00030581, year 2020
# error with legislator id N00041338, year 2018
# error with legislator id N00041338, year 2020
# error with legislator id N00004884, year 2018
# error with legislator id N00004884, year 2020
# error with legislator id N00033240, year 2018
# error with legislator id N00033240, year 2020
# error with legislator id N00004724, year 2018
# error with legislator id N00004724, year 2020
# error with legislator id N00033101, year 2018
# error with legislator id N00033101, year 2020
# error with legislator id N00029139, year 2018
# error with legislator id N00029139, year 2020
# error with legislator id N00035420, year 2018
# error with legislator id N00035420, year 2020
# error with legislator id N00034784, year 2018
# error with legislator id N00034784, year 2020
# error with legislator id N00041569, year 2018
# error with legislator id N00041569, year 2020
# error with legislator id N00004961, year 2018
# error with legislator id N00004961, year 2020
# error with legislator id N00030667, year 2018
# error with legislator id N00030667, year 2020
# error with legislator id N00033390, year 2018
# error with legislator id N00033390, year 2020
# error with legislator id N00037031, year 2018
# error with legislator id N00037031, year 2020
# error with legislator id N00004981, year 2012
# error with legislator id N00004981, year 2014
# error with legislator id N00004981, year 2016
# error with legislator id N00004981, year 2018
# error with legislator id N00004981, year 2020
# error with legislator id N00027860, year 2012
# error with legislator id N00027860, year 2014
# error with legislator id N00027860, year 2016
# error with legislator id N00027860, year 2018
# error with legislator id N00027860, year 2020
# error with legislator id N00003813, year 2018
# error with legislator id N00003813, year 2020
# error with legislator id N00031226, year 2018
# error with legislator id N00031226, year 2020
# error with legislator id N00037185, year 2018
# error with legislator id N00037185, year 2020
# error with legislator id N00041954, year 2018
# error with legislator id N00041954, year 2020
# error with legislator id N00033495, year 2018
# error with legislator id N00033495, year 2020
# error with legislator id N00041956, year 2018
# error with legislator id N00041956, year 2020
# error with legislator id N00029513, year 2018
# error with legislator id N00029513, year 2020
# error with legislator id N00031227, year 2018
# error with legislator id N00031227, year 2020
# error with legislator id N00038429, year 2018
# error with legislator id N00038429, year 2020
# error with legislator id N00041731, year 2012
# error with legislator id N00041731, year 2014
# error with legislator id N00041731, year 2016
# error with legislator id N00041731, year 2018
# error with legislator id N00041731, year 2020
# error with legislator id N00030670, year 2012
# error with legislator id N00030670, year 2014
# error with legislator id N00030670, year 2016
# error with legislator id N00030670, year 2018
# error with legislator id N00030670, year 2020
# error with legislator id N00040888, year 2018
# error with legislator id N00040888, year 2020
# error with legislator id N00027741, year 2018
# error with legislator id N00027741, year 2020
# error with legislator id N00041104, year 2018
# error with legislator id N00041104, year 2020
# error with legislator id N00025237, year 2018
# error with legislator id N00025237, year 2020
# error with legislator id N00001758, year 2012
# error with legislator id N00001758, year 2014
# error with legislator id N00001758, year 2016
# error with legislator id N00001758, year 2018
# error with legislator id N00001758, year 2020
# error with legislator id N00035483, year 2012
# error with legislator id N00035483, year 2014
# error with legislator id N00035483, year 2016
# error with legislator id N00035483, year 2018
# error with legislator id N00035483, year 2020
# error with legislator id N00037034, year 2018
# error with legislator id N00037034, year 2020
# error with legislator id N00042126, year 2018
# error with legislator id N00042126, year 2020
# error with legislator id N00042626, year 2018
# error with legislator id N00042626, year 2020
# error with legislator id N00040712, year 2018
# error with legislator id N00040712, year 2020
# error with legislator id N00005285, year 2012
# error with legislator id N00005285, year 2014
# error with legislator id N00005285, year 2016
# error with legislator id N00005285, year 2018
# error with legislator id N00005285, year 2020
# error with legislator id N00005282, year 2012
# error with legislator id N00005282, year 2014
# error with legislator id N00005282, year 2016
# error with legislator id N00005282, year 2018
# error with legislator id N00005282, year 2020
# error with legislator id N00038260, year 2018
# error with legislator id N00038260, year 2020
# error with legislator id N00029675, year 2018
# error with legislator id N00029675, year 2020
# error with legislator id N00028073, year 2018
# error with legislator id N00028073, year 2020
# error with legislator id N00034041, year 2018
# error with legislator id N00034041, year 2020
# error with legislator id N00003473, year 2018
# error with legislator id N00003473, year 2020
# error with legislator id N00031233, year 2018
# error with legislator id N00031233, year 2020
# error with legislator id N00003389, year 2012
# error with legislator id N00003389, year 2014
# error with legislator id N00003389, year 2016
# error with legislator id N00003389, year 2018
# error with legislator id N00003389, year 2020
# error with legislator id N00030836, year 2012
# error with legislator id N00030836, year 2014
# error with legislator id N00030836, year 2016
# error with legislator id N00030836, year 2018
# error with legislator id N00030836, year 2020
# error with legislator id N00009660, year 2018
# error with legislator id N00009660, year 2020
# error with legislator id N00030184, year 2018
# error with legislator id N00030184, year 2020
# error with legislator id N00039953, year 2018
# error with legislator id N00039953, year 2020
# error with legislator id N00039106, year 2018
# error with legislator id N00039106, year 2020
# error with legislator id N00036633, year 2018
# error with legislator id N00036633, year 2020
# error with legislator id N00036135, year 2018
# error with legislator id N00036135, year 2020
# error with legislator id N00030245, year 2012
# error with legislator id N00030245, year 2014
# error with legislator id N00030245, year 2016
# error with legislator id N00030245, year 2018
# error with legislator id N00030245, year 2020
# error with legislator id N00026823, year 2012
# error with legislator id N00026823, year 2014
# error with legislator id N00026823, year 2016
# error with legislator id N00026823, year 2018
# error with legislator id N00026823, year 2020
# error with legislator id N00013817, year 2018
# error with legislator id N00013817, year 2020
# error with legislator id N00041668, year 2018
# error with legislator id N00041668, year 2020
# error with legislator id N00034580, year 2012
# error with legislator id N00034580, year 2014
# error with legislator id N00034580, year 2016
# error with legislator id N00034580, year 2018
# error with legislator id N00034580, year 2020
# error with legislator id N00000491, year 2012
# error with legislator id N00000491, year 2014
# error with legislator id N00000491, year 2016
# error with legislator id N00000491, year 2018
# error with legislator id N00000491, year 2020
# error with legislator id N00029147, year 2018
# error with legislator id N00029147, year 2020
# error with legislator id N00025482, year 2018
# error with legislator id N00025482, year 2020
# error with legislator id N00027751, year 2018
# error with legislator id N00027751, year 2020
# error with legislator id N00036999, year 2018
# error with legislator id N00036999, year 2020
# error with legislator id N00001821, year 2018
# error with legislator id N00001821, year 2020
# error with legislator id N00039122, year 2018
# error with legislator id N00039122, year 2020
# error with legislator id N00001971, year 2018
# error with legislator id N00001971, year 2020
# error with legislator id N00001799, year 2018
# error with legislator id N00001799, year 2020
# error with legislator id N00037036, year 2018
# error with legislator id N00037036, year 2020
# error with legislator id N00001955, year 2012
# error with legislator id N00001955, year 2014
# error with legislator id N00001955, year 2016
# error with legislator id N00001955, year 2018
# error with legislator id N00001955, year 2020
# error with legislator id N00013820, year 2012
# error with legislator id N00013820, year 2014
# error with legislator id N00013820, year 2016
# error with legislator id N00013820, year 2018
# error with legislator id N00013820, year 2020
# error with legislator id N00000153, year 2018
# error with legislator id N00000153, year 2020
# error with legislator id N00000179, year 2018
# error with legislator id N00000179, year 2020
# error with legislator id N00041808, year 2018
# error with legislator id N00041808, year 2020
# error with legislator id N00034044, year 2018
# error with legislator id N00034044, year 2020
# error with legislator id N00035278, year 2018
# error with legislator id N00035278, year 2020
# error with legislator id N00035431, year 2018
# error with legislator id N00035431, year 2020
# error with legislator id N00042581, year 2018
# error with legislator id N00042581, year 2020
# error with legislator id N00013855, year 2018
# error with legislator id N00013855, year 2020
# error with legislator id N00031933, year 2018
# error with legislator id N00031933, year 2020
# error with legislator id N00033492, year 2012
# error with legislator id N00033492, year 2014
# error with legislator id N00033492, year 2016
# error with legislator id N00033492, year 2018
# error with legislator id N00033492, year 2020
# error with legislator id N00000270, year 2012
# error with legislator id N00000270, year 2014
# error with legislator id N00000270, year 2016
# error with legislator id N00000270, year 2018
# error with legislator id N00000270, year 2020
# error with legislator id N00039533, year 2018
# error with legislator id N00039533, year 2020
# error with legislator id N00030673, year 2018
# error with legislator id N00030673, year 2020
# error with legislator id N00031938, year 2018
# error with legislator id N00031938, year 2020
# error with legislator id N00036275, year 2018
# error with legislator id N00036275, year 2020
# error with legislator id N00033395, year 2018
# error with legislator id N00033395, year 2020
# error with legislator id N00004133, year 2018
# error with legislator id N00004133, year 2020
# error with legislator id N00026368, year 2018
# error with legislator id N00026368, year 2020
# error with legislator id N00041357, year 2018
# error with legislator id N00041357, year 2020
# error with legislator id N00042149, year 2018
# error with legislator id N00042149, year 2020
# error with legislator id N00036274, year 2018
# error with legislator id N00036274, year 2020
# error with legislator id N00040915, year 2018
# error with legislator id N00040915, year 2020
# error with legislator id N00036149, year 2018
# error with legislator id N00036149, year 2020
# error with legislator id N00042649, year 2018
# error with legislator id N00042649, year 2020
# error with legislator id N00034068, year 2018
# error with legislator id N00034068, year 2020
# error with legislator id N00029277, year 2012
# error with legislator id N00029277, year 2014
# error with legislator id N00029277, year 2016
# error with legislator id N00029277, year 2018
# error with legislator id N00029277, year 2020
# error with legislator id N00004118, year 2012
# error with legislator id N00004118, year 2014
# error with legislator id N00004118, year 2016
# error with legislator id N00004118, year 2018
# error with legislator id N00004118, year 2020
# error with legislator id N00031390, year 2018
# error with legislator id N00031390, year 2020
# error with legislator id N00037039, year 2018
# error with legislator id N00037039, year 2020
# error with legislator id N00041134, year 2018
# error with legislator id N00041134, year 2020
# error with legislator id N00012942, year 2018
# error with legislator id N00012942, year 2020
# error with legislator id N00043581, year 2018
# error with legislator id N00043581, year 2020
# error with legislator id N00035440, year 2018
# error with legislator id N00035440, year 2020
# error with legislator id N00004558, year 2018
# error with legislator id N00004558, year 2020
# error with legislator id N00041511, year 2018
# error with legislator id N00041511, year 2020
# error with legislator id N00042353, year 2012
# error with legislator id N00042353, year 2014
# error with legislator id N00042353, year 2016
# error with legislator id N00042353, year 2018
# error with legislator id N00042353, year 2020
# error with legislator id N00027500, year 2012
# error with legislator id N00027500, year 2014
# error with legislator id N00027500, year 2016
# error with legislator id N00027500, year 2018
# error with legislator id N00027500, year 2020
# error with legislator id N00037003, year 2018
# error with legislator id N00037003, year 2020
# error with legislator id N00003288, year 2018
# error with legislator id N00003288, year 2020
# error with legislator id N00042458, year 2018
# error with legislator id N00042458, year 2020
# error with legislator id N00031958, year 2018
# error with legislator id N00031958, year 2020
# error with legislator id N00043298, year 2012
# error with legislator id N00043298, year 2014
# error with legislator id N00043298, year 2016
# error with legislator id N00043298, year 2018
# error with legislator id N00043298, year 2020
# error with legislator id N00003280, year 2012
# error with legislator id N00003280, year 2014
# error with legislator id N00003280, year 2016
# error with legislator id N00003280, year 2018
# error with legislator id N00003280, year 2020
# error with legislator id N00012460, year 2018
# error with legislator id N00012460, year 2020
# error with legislator id N00033106, year 2018
# error with legislator id N00033106, year 2020
# error with legislator id N00030026, year 2018
# error with legislator id N00030026, year 2020
# error with legislator id N00031005, year 2018
# error with legislator id N00031005, year 2020
# error with legislator id N00026790, year 2018
# error with legislator id N00026790, year 2020
# error with legislator id N00013323, year 2018
# error with legislator id N00013323, year 2020
# error with legislator id N00030676, year 2018
# error with legislator id N00030676, year 2020
# error with legislator id N00035282, year 2018
# error with legislator id N00035282, year 2020
# error with legislator id N00005195, year 2012
# error with legislator id N00005195, year 2014
# error with legislator id N00005195, year 2016
# error with legislator id N00005195, year 2018
# error with legislator id N00005195, year 2020
# error with legislator id N00041620, year 2012
# error with legislator id N00041620, year 2014
# error with legislator id N00041620, year 2016
# error with legislator id N00041620, year 2018
# error with legislator id N00041620, year 2020
# error with legislator id N00040733, year 2018
# error with legislator id N00040733, year 2020
# error with legislator id N00027605, year 2012
# error with legislator id N00027605, year 2014
# error with legislator id N00027605, year 2016
# error with legislator id N00027605, year 2018
# error with legislator id N00027605, year 2020
# error with legislator id N00033054, year 2012
# error with legislator id N00033054, year 2014
# error with legislator id N00033054, year 2016
# error with legislator id N00033054, year 2018
# error with legislator id N00033054, year 2020
# error with legislator id N00026631, year 2018
# error with legislator id N00026631, year 2020
# error with legislator id N00037049, year 2018
# error with legislator id N00037049, year 2020
# error with legislator id N00027623, year 2018
# error with legislator id N00027623, year 2020
# error with legislator id N00033443, year 2012
# error with legislator id N00033443, year 2014
# error with legislator id N00033443, year 2016
# error with legislator id N00033443, year 2018
# error with legislator id N00033443, year 2020
# error with legislator id N00035544, year 2012
# error with legislator id N00035544, year 2014
# error with legislator id N00035544, year 2016
# error with legislator id N00035544, year 2018
# error with legislator id N00035544, year 2020
# error with legislator id N00030191, year 2018
# error with legislator id N00030191, year 2020
# error with legislator id N00031177, year 2018
# error with legislator id N00031177, year 2020
# error with legislator id N00037247, year 2018
# error with legislator id N00037247, year 2020
# error with legislator id N00033638, year 2018
# error with legislator id N00033638, year 2020
# error with legislator id N00033638, year 2018
# error with legislator id N00033638, year 2020
# error with legislator id N00038734, year 2012
# error with legislator id N00038734, year 2014
# error with legislator id N00038734, year 2016
# error with legislator id N00038734, year 2018
# error with legislator id N00038734, year 2020
# error with legislator id N00037161, year 2012
# error with legislator id N00037161, year 2014
# error with legislator id N00037161, year 2016
# error with legislator id N00037161, year 2018
# error with legislator id N00037161, year 2020
# error with legislator id N00042161, year 2018
# error with legislator id N00042161, year 2020
# error with legislator id N00030875, year 2018
# error with legislator id N00030875, year 2020
# error with legislator id N00038397, year 2012
# error with legislator id N00038397, year 2014
# error with legislator id N00038397, year 2016
# error with legislator id N00038397, year 2018
# error with legislator id N00038397, year 2020
# error with legislator id N00024790, year 2012
# error with legislator id N00024790, year 2014
# error with legislator id N00024790, year 2016
# error with legislator id N00024790, year 2018
# error with legislator id N00024790, year 2020
# error with legislator id N00036154, year 2018
# error with legislator id N00036154, year 2020
# error with legislator id N00042164, year 2018
# error with legislator id N00042164, year 2020
# error with legislator id N00041370, year 2018
# error with legislator id N00041370, year 2020
# error with legislator id N00009816, year 2018
# error with legislator id N00009816, year 2020
# error with legislator id N00036944, year 2018
# error with legislator id N00036944, year 2020
# error with legislator id N00000781, year 2018
# error with legislator id N00000781, year 2020
# error with legislator id N00041843, year 2018
# error with legislator id N00041843, year 2020
# error with legislator id N00027523, year 2018
# error with legislator id N00027523, year 2020
# error with legislator id N00000751, year 2018
# error with legislator id N00000751, year 2020
# error with legislator id N00034639, year 2018
# error with legislator id N00034639, year 2020
# error with legislator id N00041154, year 2018
# error with legislator id N00041154, year 2020
# error with legislator id N00036158, year 2018
# error with legislator id N00036158, year 2020
# error with legislator id N00000699, year 2012
# error with legislator id N00000699, year 2014
# error with legislator id N00000699, year 2016
# error with legislator id N00000699, year 2018
# error with legislator id N00000699, year 2020
# error with legislator id N00035267, year 2012
# error with legislator id N00035267, year 2014
# error with legislator id N00035267, year 2016
# error with legislator id N00035267, year 2018
# error with legislator id N00035267, year 2020
# error with legislator id N00040933, year 2018
# error with legislator id N00040933, year 2020
# error with legislator id N00042467, year 2018
# error with legislator id N00042467, year 2020
# error with legislator id N00029562, year 2018
# error with legislator id N00029562, year 2020
# error with legislator id N00029835, year 2012
# error with legislator id N00029835, year 2014
# error with legislator id N00029835, year 2016
# error with legislator id N00029835, year 2018
# error with legislator id N00029835, year 2020
# error with legislator id N00006561, year 2012
# error with legislator id N00006561, year 2014
# error with legislator id N00006561, year 2016
# error with legislator id N00006561, year 2018
# error with legislator id N00006561, year 2020
# error with legislator id N00029404, year 2018
# error with legislator id N00029404, year 2020
# error with legislator id N00001193, year 2018
# error with legislator id N00001193, year 2020
# error with legislator id N00038742, year 2018
# error with legislator id N00038742, year 2020
# error with legislator id N00035927, year 2018
# error with legislator id N00035927, year 2020
# error with legislator id N00001171, year 2018
# error with legislator id N00001171, year 2020
# error with legislator id N00034547, year 2018
# error with legislator id N00034547, year 2020
# error with legislator id N00001102, year 2018
# error with legislator id N00001102, year 2020
# error with legislator id N00033640, year 2018
# error with legislator id N00033640, year 2020
# error with legislator id N00026961, year 2018
# error with legislator id N00026961, year 2020
# error with legislator id N00000939, year 2018
# error with legislator id N00000939, year 2020
# error with legislator id N00041588, year 2018
# error with legislator id N00041588, year 2020
# error with legislator id N00000078, year 2018
# error with legislator id N00000078, year 2020
# error with legislator id N00034549, year 2018
# error with legislator id N00034549, year 2020
# error with legislator id N00041162, year 2018
# error with legislator id N00041162, year 2020
# error with legislator id N00001813, year 2018
# error with legislator id N00001813, year 2020
# error with legislator id N00001003, year 2018
# error with legislator id N00001003, year 2020
# error with legislator id N00001024, year 2018
# error with legislator id N00001024, year 2020
# error with legislator id N00034277, year 2018
# error with legislator id N00034277, year 2020
# error with legislator id N00040741, year 2018
# error with legislator id N00040741, year 2020
# error with legislator id N00030196, year 2018
# error with legislator id N00030196, year 2020
# error with legislator id N00035523, year 2018
# error with legislator id N00035523, year 2020
# error with legislator id N00041385, year 2018
# error with legislator id N00041385, year 2020
# error with legislator id N00030949, year 2018
# error with legislator id N00030949, year 2020
# error with legislator id N00035934, year 2018
# error with legislator id N00035934, year 2020
# error with legislator id N00043207, year 2018
# error with legislator id N00043207, year 2020
# error with legislator id N00027060, year 2018
# error with legislator id N00027060, year 2020
# error with legislator id N00001285, year 2018
# error with legislator id N00001285, year 2020
# error with legislator id N00027658, year 2012
# error with legislator id N00027658, year 2014
# error with legislator id N00027658, year 2016
# error with legislator id N00027658, year 2018
# error with legislator id N00027658, year 2020
# error with legislator id N00001093, year 2012
# error with legislator id N00001093, year 2014
# error with legislator id N00001093, year 2016
# error with legislator id N00001093, year 2018
# error with legislator id N00001093, year 2020
# error with legislator id N00027035, year 2018
# error with legislator id N00027035, year 2020
# error with legislator id N00033399, year 2018
# error with legislator id N00033399, year 2020
# error with legislator id N00002299, year 2018
# error with legislator id N00002299, year 2020
# error with legislator id N00044027, year 2018
# error with legislator id N00044027, year 2020
# error with legislator id N00002260, year 2018
# error with legislator id N00002260, year 2020
# error with legislator id N00026166, year 2018
# error with legislator id N00026166, year 2020
# error with legislator id N00035311, year 2018
# error with legislator id N00035311, year 2020
# error with legislator id N00033527, year 2018
# error with legislator id N00033527, year 2020
# error with legislator id N00033630, year 2018
# error with legislator id N00033630, year 2020
# error with legislator id N00044335, year 2018
# error with legislator id N00044335, year 2020
# error with legislator id N00026627, year 2018
# error with legislator id N00026627, year 2020
# error with legislator id N00033631, year 2018
# error with legislator id N00033631, year 2020
# error with legislator id N00035451, year 2018
# error with legislator id N00035451, year 2020
# error with legislator id N00039551, year 2018
# error with legislator id N00039551, year 2020
# error with legislator id N00035492, year 2012
# error with legislator id N00035492, year 2014
# error with legislator id N00035492, year 2016
# error with legislator id N00035492, year 2018
# error with legislator id N00035492, year 2020
# error with legislator id N00002221, year 2012
# error with legislator id N00002221, year 2014
# error with legislator id N00002221, year 2016
# error with legislator id N00002221, year 2018
# error with legislator id N00002221, year 2020
# error with legislator id N00042868, year 2018
# error with legislator id N00042868, year 2020
# error with legislator id N00031688, year 2012
# error with legislator id N00031688, year 2014
# error with legislator id N00031688, year 2016
# error with legislator id N00031688, year 2018
# error with legislator id N00031688, year 2020
# error with legislator id N00004614, year 2012
# error with legislator id N00004614, year 2014
# error with legislator id N00004614, year 2016
# error with legislator id N00004614, year 2018
# error with legislator id N00004614, year 2020
# error with legislator id N00003689, year 2018
# error with legislator id N00003689, year 2020
# error with legislator id N00033310, year 2018
# error with legislator id N00033310, year 2020
# error with legislator id N00033904, year 2018
# error with legislator id N00033904, year 2020
# error with legislator id N00027894, year 2018
# error with legislator id N00027894, year 2020
# error with legislator id N00012233, year 2018
# error with legislator id N00012233, year 2020
# error with legislator id N00032088, year 2018
# error with legislator id N00032088, year 2020
# error with legislator id N00031128, year 2018
# error with legislator id N00031128, year 2020
# error with legislator id N00038767, year 2018
# error with legislator id N00038767, year 2020
# error with legislator id N00003522, year 2018
# error with legislator id N00003522, year 2020
# error with legislator id N00025175, year 2018
# error with legislator id N00025175, year 2020
# error with legislator id N00030490, year 2018
# error with legislator id N00030490, year 2020
# error with legislator id N00042194, year 2018
# error with legislator id N00042194, year 2020
# error with legislator id N00025280, year 2018
# error with legislator id N00025280, year 2020
# error with legislator id N00035007, year 2018
# error with legislator id N00035007, year 2020
# error with legislator id N00029574, year 2018
# error with legislator id N00029574, year 2020
# error with legislator id N00041690, year 2018
# error with legislator id N00041690, year 2020
# error with legislator id N00003535, year 2012
# error with legislator id N00003535, year 2014
# error with legislator id N00003535, year 2016
# error with legislator id N00003535, year 2018
# error with legislator id N00003535, year 2020
# error with legislator id N00003682, year 2012
# error with legislator id N00003682, year 2014
# error with legislator id N00003682, year 2016
# error with legislator id N00003682, year 2018
# error with legislator id N00003682, year 2020
# error with legislator id N00040829, year 2018
# error with legislator id N00040829, year 2020
# error with legislator id N00033410, year 2018
# error with legislator id N00033410, year 2020
# error with legislator id N00005559, year 2018
# error with legislator id N00005559, year 2020
# error with legislator id N00025726, year 2018
# error with legislator id N00025726, year 2020
# error with legislator id N00041394, year 2018
# error with legislator id N00041394, year 2020
# error with legislator id N00031129, year 2012
# error with legislator id N00031129, year 2014
# error with legislator id N00031129, year 2016
# error with legislator id N00031129, year 2018
# error with legislator id N00031129, year 2020
# error with legislator id N00005582, year 2012
# error with legislator id N00005582, year 2014
# error with legislator id N00005582, year 2016
# error with legislator id N00005582, year 2018
# error with legislator id N00005582, year 2020
# error with legislator id N00033474, year 2018
# error with legislator id N00033474, year 2020
# error with legislator id N00007690, year 2018
# error with legislator id N00007690, year 2020
# error with legislator id N00007727, year 2018
# error with legislator id N00007727, year 2020
# error with legislator id N00007781, year 2018
# error with legislator id N00007781, year 2020
# error with legislator id N00030071, year 2018
# error with legislator id N00030071, year 2020
# error with legislator id N00029303, year 2012
# error with legislator id N00029303, year 2014
# error with legislator id N00029303, year 2016
# error with legislator id N00029303, year 2018
# error with legislator id N00029303, year 2020
# error with legislator id N00007724, year 2012
# error with legislator id N00007724, year 2014
# error with legislator id N00007724, year 2016
# error with legislator id N00007724, year 2018
# error with legislator id N00007724, year 2020
# error with legislator id N00038779, year 2018
# error with legislator id N00038779, year 2020
# error with legislator id N00035307, year 2018
# error with legislator id N00035307, year 2020
# error with legislator id N00038450, year 2018
# error with legislator id N00038450, year 2020
# error with legislator id N00042894, year 2018
# error with legislator id N00042894, year 2020
# error with legislator id N00042706, year 2018
# error with legislator id N00042706, year 2020
# error with legislator id N00040949, year 2018
# error with legislator id N00040949, year 2020
# error with legislator id N00041997, year 2018
# error with legislator id N00041997, year 2020
# error with legislator id N00034128, year 2018
# error with legislator id N00034128, year 2020
# error with legislator id N00029416, year 2018
# error with legislator id N00029416, year 2020
# error with legislator id N00034120, year 2018
# error with legislator id N00034120, year 2020
# error with legislator id N00038781, year 2018
# error with legislator id N00038781, year 2020
# error with legislator id N00031777, year 2018
# error with legislator id N00031777, year 2020
# error with legislator id N00044065, year 2018
# error with legislator id N00044065, year 2020
# error with legislator id N00043242, year 2018
# error with legislator id N00043242, year 2020
# error with legislator id N00041871, year 2018
# error with legislator id N00041871, year 2020
# error with legislator id N00029736, year 2018
# error with legislator id N00029736, year 2020
# error with legislator id N00031647, year 2018
# error with legislator id N00031647, year 2020
# error with legislator id N00041870, year 2018
# error with legislator id N00041870, year 2020
# error with legislator id N00001373, year 2018
# error with legislator id N00001373, year 2020
# error with legislator id N00001489, year 2012
# error with legislator id N00001489, year 2014
# error with legislator id N00001489, year 2016
# error with legislator id N00001489, year 2018
# error with legislator id N00001489, year 2020
# error with legislator id N00027503, year 2012
# error with legislator id N00027503, year 2014
# error with legislator id N00027503, year 2016
# error with legislator id N00027503, year 2018
# error with legislator id N00027503, year 2020
# error with legislator id N00032019, year 2018
# error with legislator id N00032019, year 2020
# error with legislator id N00009724, year 2018
# error with legislator id N00009724, year 2020
# error with legislator id N00027533, year 2012
# error with legislator id N00027533, year 2014
# error with legislator id N00027533, year 2016
# error with legislator id N00027533, year 2018
# error with legislator id N00027533, year 2020
# error with legislator id N00000362, year 2012
# error with legislator id N00000362, year 2014
# error with legislator id N00000362, year 2016
# error with legislator id N00000362, year 2018
# error with legislator id N00000362, year 2020
# error with legislator id N00041400, year 2018
# error with legislator id N00041400, year 2020
# error with legislator id N00024809, year 2018
# error with legislator id N00024809, year 2020
# error with legislator id N00030752, year 2018
# error with legislator id N00030752, year 2020
# error with legislator id N00042715, year 2018
# error with legislator id N00042715, year 2020
# error with legislator id N00027783, year 2018
# error with legislator id N00027783, year 2020
# error with legislator id N00002408, year 2018
# error with legislator id N00002408, year 2020
# error with legislator id N00033832, year 2018
# error with legislator id N00033832, year 2020
# error with legislator id N00031782, year 2012
# error with legislator id N00031782, year 2014
# error with legislator id N00031782, year 2016
# error with legislator id N00031782, year 2018
# error with legislator id N00031782, year 2020
# error with legislator id N00009975, year 2012
# error with legislator id N00009975, year 2014
# error with legislator id N00009975, year 2016
# error with legislator id N00009975, year 2018
# error with legislator id N00009975, year 2020
# error with legislator id N00040559, year 2018
# error with legislator id N00040559, year 2020
# error with legislator id N00004572, year 2012
# error with legislator id N00004572, year 2014
# error with legislator id N00004572, year 2016
# error with legislator id N00004572, year 2018
# error with legislator id N00004572, year 2020
# error with legislator id N00035187, year 2012
# error with legislator id N00035187, year 2014
# error with legislator id N00035187, year 2016
# error with legislator id N00035187, year 2018
# error with legislator id N00035187, year 2020
# error with legislator id N00028463, year 2018
# error with legislator id N00028463, year 2020
# error with legislator id N00041594, year 2018
# error with legislator id N00041594, year 2020
# error with legislator id N00030815, year 2018
# error with legislator id N00030815, year 2020
# error with legislator id N00030957, year 2018
# error with legislator id N00030957, year 2020
# error with legislator id N00003132, year 2018
# error with legislator id N00003132, year 2020
# error with legislator id N00041599, year 2018
# error with legislator id N00041599, year 2020
# error with legislator id N00041873, year 2018
# error with legislator id N00041873, year 2020
# error with legislator id N00025445, year 2018
# error with legislator id N00025445, year 2020
# error with legislator id N00003225, year 2018
# error with legislator id N00003225, year 2020
# error with legislator id N00003105, year 2012
# error with legislator id N00003105, year 2014
# error with legislator id N00003105, year 2016
# error with legislator id N00003105, year 2018
# error with legislator id N00003105, year 2020
# error with legislator id N00009888, year 2012
# error with legislator id N00009888, year 2014
# error with legislator id N00009888, year 2016
# error with legislator id N00009888, year 2018
# error with legislator id N00009888, year 2020
# error with legislator id N00026148, year 2018
# error with legislator id N00026148, year 2020
# error with legislator id N00042224, year 2018
# error with legislator id N00042224, year 2020
# error with legislator id N00027709, year 2018
# error with legislator id N00027709, year 2020
# error with legislator id N00035972, year 2018
# error with legislator id N00035972, year 2020
# error with legislator id N00042237, year 2018
# error with legislator id N00042237, year 2020
# error with legislator id N00042240, year 2018
# error with legislator id N00042240, year 2020
# error with legislator id N00041194, year 2018
# error with legislator id N00041194, year 2020
# error with legislator id N00005883, year 2018
# error with legislator id N00005883, year 2020
# error with legislator id N00026686, year 2018
# error with legislator id N00026686, year 2020
# error with legislator id N00026460, year 2018
# error with legislator id N00026460, year 2020
# error with legislator id N00026041, year 2018
# error with legislator id N00026041, year 2020
# error with legislator id N00008799, year 2018
# error with legislator id N00008799, year 2020
# error with legislator id N00006052, year 2018
# error with legislator id N00006052, year 2020
# error with legislator id N00033539, year 2018
# error with legislator id N00033539, year 2020
# error with legislator id N00038809, year 2018
# error with legislator id N00038809, year 2020
# error with legislator id N00041702, year 2018
# error with legislator id N00041702, year 2020
# error with legislator id N00031545, year 2018
# error with legislator id N00031545, year 2020
# error with legislator id N00005818, year 2018
# error with legislator id N00005818, year 2020
# error with legislator id N00038285, year 2018
# error with legislator id N00038285, year 2020
# error with legislator id N00033316, year 2018
# error with legislator id N00033316, year 2020
# error with legislator id N00042268, year 2018
# error with legislator id N00042268, year 2020
# error with legislator id N00029285, year 2018
# error with legislator id N00029285, year 2020
# error with legislator id N00031417, year 2018
# error with legislator id N00031417, year 2020
# error with legislator id N00026710, year 2018
# error with legislator id N00026710, year 2020
# error with legislator id N00030602, year 2018
# error with legislator id N00030602, year 2020
# error with legislator id N00025219, year 2018
# error with legislator id N00025219, year 2020
# error with legislator id N00041882, year 2018
# error with legislator id N00041882, year 2020
# error with legislator id N00024978, year 2018
# error with legislator id N00024978, year 2020
# error with legislator id N00042282, year 2018
# error with legislator id N00042282, year 2020
# error with legislator id N00008122, year 2018
# error with legislator id N00008122, year 2020
# error with legislator id N00025095, year 2018
# error with legislator id N00025095, year 2020
# error with legislator id N00040989, year 2018
# error with legislator id N00040989, year 2020
# error with legislator id N00033839, year 2018
# error with legislator id N00033839, year 2020
# error with legislator id N00034349, year 2018
# error with legislator id N00034349, year 2020
# error with legislator id N00006023, year 2018
# error with legislator id N00006023, year 2020
# error with legislator id N00005736, year 2018
# error with legislator id N00005736, year 2020
# error with legislator id N00024852, year 2012
# error with legislator id N00024852, year 2014
# error with legislator id N00024852, year 2016
# error with legislator id N00024852, year 2018
# error with legislator id N00024852, year 2020
# error with legislator id N00033085, year 2012
# error with legislator id N00033085, year 2014
# error with legislator id N00033085, year 2016
# error with legislator id N00033085, year 2018
# error with legislator id N00033085, year 2020
# error with legislator id N00025292, year 2018
# error with legislator id N00025292, year 2020
# error with legislator id N00033932, year 2018
# error with legislator id N00033932, year 2020
# error with legislator id N00041221, year 2018
# error with legislator id N00041221, year 2020
# error with legislator id N00042013, year 2018
# error with legislator id N00042013, year 2020
# error with legislator id N00000286, year 2012
# error with legislator id N00000286, year 2014
# error with legislator id N00000286, year 2016
# error with legislator id N00000286, year 2018
# error with legislator id N00000286, year 2020
# error with legislator id N00031696, year 2012
# error with legislator id N00031696, year 2014
# error with legislator id N00031696, year 2016
# error with legislator id N00031696, year 2018
# error with legislator id N00031696, year 2020
# error with legislator id N00000515, year 2018
# error with legislator id N00000515, year 2020
# error with legislator id N00000528, year 2012
# error with legislator id N00000528, year 2014
# error with legislator id N00000528, year 2016
# error with legislator id N00000528, year 2018
# error with legislator id N00000528, year 2020
# error with legislator id N00009918, year 2012
# error with legislator id N00009918, year 2014
# error with legislator id N00009918, year 2016
# error with legislator id N00009918, year 2018
# error with legislator id N00009918, year 2020
# error with legislator id N00029459, year 2018
# error with legislator id N00029459, year 2020
# error with legislator id N00042293, year 2018
# error with legislator id N00042293, year 2020
# error with legislator id N00002147, year 2018
# error with legislator id N00002147, year 2020
# error with legislator id N00039327, year 2018
# error with legislator id N00039327, year 2020
# error with legislator id N00043541, year 2018
# error with legislator id N00043541, year 2020
# error with legislator id N00042296, year 2018
# error with legislator id N00042296, year 2020
# error with legislator id N00041418, year 2018
# error with legislator id N00041418, year 2020
# error with legislator id N00036018, year 2018
# error with legislator id N00036018, year 2020
# error with legislator id N00032029, year 2018
# error with legislator id N00032029, year 2020
# error with legislator id N00041002, year 2018
# error with legislator id N00041002, year 2020
# error with legislator id N00029891, year 2018
# error with legislator id N00029891, year 2020
# error with legislator id N00033177, year 2012
# error with legislator id N00033177, year 2014
# error with legislator id N00033177, year 2016
# error with legislator id N00033177, year 2018
# error with legislator id N00033177, year 2020
# error with legislator id N00002097, year 2012
# error with legislator id N00002097, year 2014
# error with legislator id N00002097, year 2016
# error with legislator id N00002097, year 2018
# error with legislator id N00002097, year 2020
# error with legislator id N00030693, year 2018
# error with legislator id N00030693, year 2020
# error with legislator id N00009759, year 2018
# error with legislator id N00009759, year 2020
# error with legislator id N00031559, year 2018
# error with legislator id N00031559, year 2020
# error with legislator id N00036403, year 2018
# error with legislator id N00036403, year 2020
# error with legislator id N00026314, year 2018
# error with legislator id N00026314, year 2020
# error with legislator id N00034453, year 2018
# error with legislator id N00034453, year 2020
# error with legislator id N00038858, year 2018
# error with legislator id N00038858, year 2020
# error with legislator id N00041606, year 2018
# error with legislator id N00041606, year 2020
# error with legislator id N00007833, year 2018
# error with legislator id N00007833, year 2020
# error with legislator id N00031557, year 2018
# error with legislator id N00031557, year 2020
# error with legislator id N00007836, year 2012
# error with legislator id N00007836, year 2014
# error with legislator id N00007836, year 2016
# error with legislator id N00007836, year 2018
# error with legislator id N00007836, year 2020
# error with legislator id N00007876, year 2012
# error with legislator id N00007876, year 2014
# error with legislator id N00007876, year 2016
# error with legislator id N00007876, year 2018
# error with legislator id N00007876, year 2020
# error with legislator id N00031681, year 2018
# error with legislator id N00031681, year 2020
# error with legislator id N00033814, year 2018
# error with legislator id N00033814, year 2020
# error with legislator id N00041542, year 2018
# error with legislator id N00041542, year 2020
# error with legislator id N00032838, year 2012
# error with legislator id N00032838, year 2014
# error with legislator id N00032838, year 2016
# error with legislator id N00032838, year 2018
# error with legislator id N00032838, year 2020
# error with legislator id N00009771, year 2012
# error with legislator id N00009771, year 2014
# error with legislator id N00009771, year 2016
# error with legislator id N00009771, year 2018
# error with legislator id N00009771, year 2020
# error with legislator id N00043379, year 2018
# error with legislator id N00043379, year 2020
# error with legislator id N00033549, year 2018
# error with legislator id N00033549, year 2020
# error with legislator id N00004403, year 2018
# error with legislator id N00004403, year 2020
# error with legislator id N00026914, year 2018
# error with legislator id N00026914, year 2020
# error with legislator id N00004291, year 2018
# error with legislator id N00004291, year 2020
# error with legislator id N00036409, year 2018
# error with legislator id N00036409, year 2020
# error with legislator id N00030967, year 2018
# error with legislator id N00030967, year 2020
# error with legislator id N00045307, year 2018
# error with legislator id N00045307, year 2020
# error with legislator id N00039330, year 2018
# error with legislator id N00039330, year 2020
# error with legislator id N00004367, year 2012
# error with legislator id N00004367, year 2014
# error with legislator id N00004367, year 2016
# error with legislator id N00004367, year 2018
# error with legislator id N00004367, year 2020
# error with legislator id N00032546, year 2012
# error with legislator id N00032546, year 2014
# error with legislator id N00032546, year 2016
# error with legislator id N00032546, year 2018
# error with legislator id N00032546, year 2020
# error with legislator id N00035504, year 2018
# error with legislator id N00035504, year 2020
# error with legislator id N00006236, year 2012
# error with legislator id N00006236, year 2014
# error with legislator id N00006236, year 2016
# error with legislator id N00006236, year 2018
# error with legislator id N00006236, year 2020
# error with legislator id N00006249, year 2012
# error with legislator id N00006249, year 2014
# error with legislator id N00006249, year 2016
# error with legislator id N00006249, year 2018
# error with legislator id N00006249, year 2020

# %%
cand_contrib[-1][0]['@attributes']['cid'] = 'foo'
cand_contrib[-1][0]['@attributes']
# Out:
# {'org_name': 'DISH Network',
#  'total': '13500',
#  'pacs': '0',
#  'indivs': '13500',
#  'cid': 'foo'}

# %%
df_legislators.head(1)
# Out:
#          cid      firstlast lastname party office gender first_elected  \
# 0  N00035380  Bradley Byrne    BYRNE     R   AL01      M          2013
#
#   exit_code             comments         phone  ...                  website  \
# 0        20  Lost Senate primary  202-225-4931  ...  https://byrne.house.gov
#
#                                     webform                   congress_office  \
# 0  https://byrne.house.gov/contact/email-me  119 Cannon House Office Building
#
#   bioguide_id votesmart_id  feccandid twitter_id youtube_url facebook_id  \
# 0     B001289        27584  H4AL01123   RepByrne                RepByrne
#
#     birthdate
# 0  1955-02-16
#
# [1 rows x 21 columns]

# %%
crp.candidates.summary(df_legislators.iloc[0]['cid'],cycle='2018')
# Out:
# {'cand_name': 'Byrne, Bradley',
#  'cid': 'N00035380',
#  'cycle': '2018',
#  'state': 'AL',
#  'party': 'R',
#  'chamber': 'H',
#  'first_elected': '2013',
#  'next_election': '2018',
#  'total': '1460040.82',
#  'spent': '831634.13',
#  'cash_on_hand': '1074725.02',
#  'debt': '0',
#  'origin': 'Center for Responsive Politics',
#  'source': 'https://www.opensecrets.org/members-of-congress/summary?cid=N00035380&cycle=2018',
#  'last_updated': '12/31/2018'}

# %%
# define method to get generalized data for each legislator in df_legislators
def get_crp_cand_method_data(df,meth,current_calls = 0, sen_years=['2012','2014','2016','2018','2020'],rep_years=['2018','2020'],last_cid=None,last_year=None):
    max_calls_dict = {'pfd': 2000, 'summary': 2000, 'contrib': 200, 'industries': 200, 'contrib_by_ind': 2000, 'sector': 200}
    max_calls = max_calls_dict[meth]
    
    cand_list = []
    
    # remove all prior cids if last_cid given
    keep_going = True
    if last_cid is not None:
        try:
            ix = df['cid'].to_list().index(last_cid)
            df = df.iloc[ix:]
        except: # just start from beginning if last_cid not in df
            print('last_cid {} not in df. starting from beginning...'.format(last_cid))
            last_cid = df.iloc[0]['cid']
        
        #  continue last_cid from last_year to last possible year
        is_senate = re.search("S[12]", df.iloc[0]['office'])
        if is_senate:
            if is_senate:
                years = sen_years
            else:
                years = rep_years

        if last_year is not None:
            years = years[years.index(last_year):]

        for year in years:
            if current_calls == max_calls:
                keep_going = False
                break
            try:
                cand_list.append(getattr(crp.candidates,meth)(last_cid,cycle=year))
                current_calls += 1
                cand_contrib[-1][0]['@attributes']['cid'] = last_cid
                cand_contrib[-1][0]['@attributes']['cycle'] = year
            except:
                print('error with legislator id {}, year {}'.format(cid,year))

            last_year = year

        # if reached limit already, return
        if keep_going is False:
            return cand_list, last_cid, last_year

        # else, continue through cids in df
        # remove last_cid (completed above) from df
        df = df.iloc[1:]
        
    for ix,cid in enumerate(df.cid):
        if keep_going is False:
            break
        is_senate = re.search("S[12]", df.iloc[ix]['office'])
        if is_senate:
            years = sen_years
        else:
            years = rep_years

        for year in years:
            if current_calls == max_calls:
                keep_going = False
                break
            try:
                cand_list.append(getattr(crp.candidates,meth)(cid,cycle=year))
                current_calls += 1
                
                cand_contrib[-1][0]['@attributes']['cid'] = cid
                cand_contrib[-1][0]['@attributes']['cycle'] = year
            except:
                print('error with legislator id {}, year {}'.format(cid,year))

            last_year = year

        last_cid = cid

    return cand_list, last_cid, last_year

# %%
# get candSummary (summary) for each legislator in df_legislators
meth = 'summary'
cand_sum, last_cid_sum, last_year_sum = get_crp_cand_method_data(df_legislators,meth=meth,current_calls=16)
# Out:
# error with legislator id N00024817, year 2012
# error with legislator id N00024817, year 2014
# error with legislator id N00024817, year 2016
# error with legislator id N00035774, year 2012
# error with legislator id N00040644, year 2020
# error with legislator id N00044298, year 2018
# error with legislator id N00036915, year 2012
# error with legislator id N00036915, year 2014
# error with legislator id N00043290, year 2012
# error with legislator id N00043290, year 2014
# error with legislator id N00043290, year 2016
# error with legislator id N00035516, year 2012
# error with legislator id N00046125, year 2012
# error with legislator id N00046125, year 2014
# error with legislator id N00046125, year 2016
# error with legislator id N00046125, year 2018
# error with legislator id N00028138, year 2012
# error with legislator id N00041731, year 2012
# error with legislator id N00041731, year 2014
# error with legislator id N00041731, year 2016
# error with legislator id N00035483, year 2012
# error with legislator id N00001799, year 2018
# error with legislator id N00031938, year 2020
# error with legislator id N00042353, year 2012
# error with legislator id N00042353, year 2014
# error with legislator id N00042353, year 2016
# error with legislator id N00043298, year 2012
# error with legislator id N00043298, year 2014
# error with legislator id N00043298, year 2016
# error with legislator id N00041620, year 2012
# error with legislator id N00041620, year 2014
# error with legislator id N00041620, year 2016
# error with legislator id N00035544, year 2012
# error with legislator id N00038734, year 2012
# error with legislator id N00038734, year 2014
# error with legislator id N00037161, year 2012
# error with legislator id N00037161, year 2014
# error with legislator id N00038397, year 2012
# error with legislator id N00038397, year 2014
# error with legislator id N00035267, year 2012
# error with legislator id N00002299, year 2020
# error with legislator id N00044027, year 2018
# error with legislator id N00044335, year 2018
# error with legislator id N00035492, year 2012
# error with legislator id N00044065, year 2018
# error with legislator id N00000286, year 2014
# error with legislator id N00000286, year 2016
# error with legislator id N00045307, year 2018

# %%
import pickle
mem_pfd_cid_errors = ['N00035187','N00009918']
data_to_save = (df_legislators,(mem_pfd_profiles,mem_pfd_cid_errors),(cand_sum, last_cid_sum, last_year_sum))
with open('20200621_fetched_api_data_opensecrets.pickle', 'wb') as to_write:
    pickle.dump(data_to_save, to_write)

# %%
##################################################################################################################
##################################################################################################################
##################################################################################################################

# %%
# get candIndustry (industries) for each legislator in df_legislators
meth = 'industries'
cand_ind, last_cid_ind, last_year_ind = get_crp_cand_method_data(df_legislators,meth=meth)

# %%
# get candIndByInd (contrib_by_ind)for each legislator in df_legislators
meth = 'contrib_by_ind'
cand_ind_by_ind, last_cid_ind_by_ind, last_year_ind_by_ind = get_crp_cand_method_data(df_legislators,meth=meth)

# %%
# get candSector (sector) for each legislator in df_legislators
meth = 'sector'
cand_ind_sector, last_cid_sector, last_year_sector = get_crp_cand_method_data(df_legislators,meth=meth)

# %%
# get candContrib for each legislator in df_legislators
meth = 'contrib'
cand_contrib, last_cid_contrib, last_year_contrib = get_crp_cand_method_data(df_legislators,meth=meth)

# %%
# get congCmteIndus for each legislator in df_legislators
meth = 'contrib_by_ind'
cand_ind_by_ind, last_cid_ind_by_ind, last_year_ind_by_ind = get_crp_cand_method_data(df_legislators,meth=meth)

# %%
# get getOrgs for each legislator in df_legislators
meth = 'contrib_by_ind'
cand_ind_by_ind, last_cid_ind_by_ind, last_year_ind_by_ind = get_crp_cand_method_data(df_legislators,meth=meth)

# %%
# get orgSummary for each legislator in df_legislators
meth = 'contrib_by_ind'
cand_ind_by_ind, last_cid_ind_by_ind, last_year_ind_by_ind = get_crp_cand_method_data(df_legislators,meth=meth)

# %%
# get independentExpend for each legislator in df_legislators

# %%
# Out:
# <crpapi.CRP object at 0x11d268cc0>
